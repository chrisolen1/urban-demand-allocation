# %%
import censusdata

# %%
censusdata.geographies(censusdata.censusgeo([('state', '17'), ('county', '031'), ('tract', '*')]), 'acs5', 2018)
# Out:
# {'Census Tract 3109, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '310900'))),
#  'Census Tract 4205, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '420500'))),
#  'Census Tract 4304, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '430400'))),
#  'Census Tract 4306, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '430600'))),
#  'Census Tract 4409, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '440900'))),
#  'Census Tract 4601, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '460100'))),
#  'Census Tract 4805, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '480500'))),
#  'Census Tract 2831, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '283100'))),
# ...

# %%
censusdata.search('acs5', 2013, 'label', 'total population')
# Out:
# [('B25026_001E',
#   'B25026.  Total Population in Occupied Housing Units by Tenure by Year Householder Moved Into Unit',
#   'Total population in occupied housing units:'),
#  ('B25026_001M',
#   'B25026.  Total Population in Occupied Housing Units by Tenure by Year Householder Moved Into Unit',
#   'Margin of Error for!!Total population in occupied housing units:'),
#  ('B25026_002E',
#   'B25026.  Total Population in Occupied Housing Units by Tenure by Year Householder Moved Into Unit',
#   'Total population in occupied housing units:!!Owner occupied:'),
#  ('B25026_002M',
#   'B25026.  Total Population in Occupied Housing Units by Tenure by Year Householder Moved Into Unit',
#   'Margin of Error for!!Total population in occupied housing units:!!Owner occupied:'),
#  ('B25026_003E',
#   'B25026.  Total Population in Occupied Housing Units by Tenure by Year Householder Moved Into Unit',
#   'Total population in occupied housing units:!!Owner occupied:!!Moved in 2010 or later'),
# ...

# %%
censusdata.printtable(censusdata.censustable('acs5', 2013, 'B25026'))
# Out:
# Variable     | Table                          | Label                                                    | Type
# -------------------------------------------------------------------------------------------------------------------
# B25026_001E  | B25026.  Total Population in O | Total population in occupied housing units:              | int
# B25026_002E  | B25026.  Total Population in O | !! Total population in occupied housing units: Owner occ | int
# B25026_003E  | B25026.  Total Population in O | !! !! Total population in occupied housing units: Owner  | int
# B25026_004E  | B25026.  Total Population in O | !! !! Total population in occupied housing units: Owner  | int
# B25026_005E  | B25026.  Total Population in O | !! !! Total population in occupied housing units: Owner  | int
# B25026_006E  | B25026.  Total Population in O | !! !! Total population in occupied housing units: Owner  | int
# ...

# %%
pop_2010 = censusdata.download('acs5', 2010,
                             censusdata.censusgeo([('state', '17'), ('county', '031'), ('tract', '*')]),
                             ['B25026_001E'])

# %%
pop_2011 = censusdata.download('acs5', 2011,
                             censusdata.censusgeo([('state', '17'), ('county', '031'), ('tract', '*')]),
                             ['B25026_001E'])

# %%
pop_2012 = censusdata.download('acs5', 2012,
                             censusdata.censusgeo([('state', '17'), ('county', '031'), ('tract', '*')]),
                             ['B25026_001E'])

# %%
pop_2013 = censusdata.download('acs5', 2013,
                             censusdata.censusgeo([('state', '17'), ('county', '031'), ('tract', '*')]),
                             ['B25026_001E'])

# %%
pop_2014 = censusdata.download('acs5', 2014,
                             censusdata.censusgeo([('state', '17'), ('county', '031'), ('tract', '*')]),
                             ['B25026_001E'])

# %%
pop_2015 = censusdata.download('acs5', 2015,
                             censusdata.censusgeo([('state', '17'), ('county', '031'), ('tract', '*')]),
                             ['B25026_001E'])

# %%
pop_2016 = censusdata.download('acs5', 2016,
                             censusdata.censusgeo([('state', '17'), ('county', '031'), ('tract', '*')]),
                             ['B25026_001E'])

# %%
pop_2017 = censusdata.download('acs5', 2017,
                             censusdata.censusgeo([('state', '17'), ('county', '031'), ('tract', '*')]),
                             ['B25026_001E'])

# %%
pop_2018 = censusdata.download('acs5', 2018,
                             censusdata.censusgeo([('state', '17'), ('county', '031'), ('tract', '*')]),
                             ['B25026_001E'])

# %%
sum(pop_2010['B25026_001E'])
# Out:
# 5089453

# %%
sum(pop_2011['B25026_001E'])
# Out:
# 5099351

# %%
sum(pop_2012['B25026_001E'])
# Out:
# 5114489

# %%
sum(pop_2013['B25026_001E'])
# Out:
# 5127749

# %%
sum(pop_2014['B25026_001E'])
# Out:
# 5140700

# %%
sum(pop_2015['B25026_001E'])
# Out:
# 5147238

# %%
sum(pop_2016['B25026_001E'])
# Out:
# 5137167

# %%
sum(pop_2017['B25026_001E'])
# Out:
# 5146835

# %%
sum(pop_2018['B25026_001E'])
# Out:
# 5131695

# %%
censusdata.censusvar('acsse', 2010, )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-129-5deb87bd2256> in <module>
# ----> 1 censusdata.censusvar('acsse', 2010)
#
# TypeError: censusvar() missing 1 required positional argument: 'var'
