# %%
import pandas as pd

import descartes
import geopandas as gpd
from shapely.geometry import Point, Polygon

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
coordinate_matrix = pd.read_csv("coordinate_matrix.csv")

# %%
with open('opt_result.txt', 'r') as res:
    opt_result = res.readlines()
    opt_result = opt_result[0].replace("\n","")
    
opt_result
# Out:
# '20504'

# %%
coordinate_matrix.iloc[int(opt_result)]
# Out:
# Unnamed: 0                         552669
# ADDRDELIV       9221 SOUTH BENNETT AVENUE
# LATITUDE                          41.7273
# LONGITUDE                        -87.5776
# neighborhood              Calumet Heights
# Name: 20504, dtype: object

# %%
opt_result_1000 = ['52',(41.8455,-87.7023)]
opt_result_10000 = ['1967',(41.8455,-87.7023)]
opt_result_50000 = ['20495',(41.7273,-87.5776)]
opt_result_50000 = ['20504',(41.7273,-87.5776)]

# %%
opt_coord = coordinate_matrix.iloc[int(opt_result),:].to_frame().transpose()

# %%
opt_coord
# Out:
#       Unnamed: 0                  ADDRDELIV LATITUDE LONGITUDE  \
# 20495     552669  9221 SOUTH BENNETT AVENUE  41.7273  -87.5776
#
#           neighborhood
# 20495  Calumet Heights

# %%
#! SHAPE_RESTORE_SHX=YES fio info geo_export_7326bade-67ad-48f6-98c8-abed166274de.shp

street_map = gpd.read_file("plot/geo_export_7326bade-67ad-48f6-98c8-abed166274de.shp", SHAPE_RESTORE_SHX = "yes")

# %%
fix, ax = plt.subplots(figsize = (15,15))
street_map.plot(ax = ax)

# %%
crs = {'init':'epsg:4326'}

#coords = [Point(xy) for xy in zip(opt_coord['LONGITUDE'],opt_coord['LATITUDE'])]
coord = Point((opt_coord['LONGITUDE'],opt_coord['LATITUDE']))
coord

# %%
gdf = gpd.GeoDataFrame(opt_coord, geometry=gpd.points_from_xy(opt_coord["LONGITUDE"], 
                                                                         opt_coord["LATITUDE"]))

# %%
gdf
# Out:
#       Unnamed: 0                  ADDRDELIV LATITUDE LONGITUDE  \
# 20495     552669  9221 SOUTH BENNETT AVENUE  41.7273  -87.5776
#
#           neighborhood                    geometry
# 20495  Calumet Heights  POINT (-87.57760 41.72726)

# %%
fix, ax = plt.subplots(figsize = (15,15))
street_map.plot(ax = ax, alpha = 0.4, color = "grey")
gdf.plot(ax=ax, markersize=40, color="blue", marker="o")
